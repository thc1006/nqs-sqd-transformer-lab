# %% [markdown]
# # 001 - Theory sanity check
#
# Use this notebook to derive / confirm small H2 Hamiltonians, bitstring mappings,
# and any toy examples before implementing them in `src/sqd_interface/hamiltonian.py`.
#
# You can also use it to compare FFNN vs Transformer NQS on tiny toy models where
# the full Hilbert space can be enumerated.
